# %% [markdown]
# # SeeFood Part 2 — Fine-tune ResNet-50 on Food-101 (Colab)
#
# Runtime: GPU (T4 or A100). Expected wall-time on T4: ~2–4 h for 30 epochs.

# %%
# 1. Clone repo and install deps
import os, subprocess, sys
REPO_URL = 'https://github.com/clarkkuang82/SeeFood.git'  # <-- update
REPO_DIR = '/content/SeeFood'
if not os.path.isdir(REPO_DIR):
    subprocess.check_call(['git', 'clone', REPO_URL, REPO_DIR])
# %cd $REPO_DIR
# !pip -q install -r requirements.txt

# %%
# 2. Mount Drive for checkpoint persistence
from google.colab import drive
drive.mount('/content/drive')
# !mkdir -p /content/drive/MyDrive/seefood_part2/checkpoints
# !ln -sfn /content/drive/MyDrive/seefood_part2/checkpoints $REPO_DIR/part2_finetune_resnet50/checkpoints

# %%
# 3. GPU check
import torch
print('cuda:', torch.cuda.is_available(), torch.cuda.get_device_name(0) if torch.cuda.is_available() else '')

# %%
# 4. Full training run (~2–4 h on T4)
# !python part2_finetune_resnet50/train.py --config part2_finetune_resnet50/configs/full_finetune.yaml

# %%
# 5. Test-set evaluation
# !python part2_finetune_resnet50/eval.py \
    --config part2_finetune_resnet50/configs/full_finetune.yaml \
    --ckpt part2_finetune_resnet50/checkpoints/best.pt

# %%
# 6. Inspect results
import json, pathlib
print(json.dumps(json.load(open('part2_finetune_resnet50/results/metrics.json')), indent=2)[:2000])
from IPython.display import Image
Image('part2_finetune_resnet50/results/training_curves.png')
